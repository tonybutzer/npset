# %%
#! mkdir -p anim

# %%
! ls
# Out:
# 00-00-DEMO-PNG-CREATION-to-S3-BUCKET.ipynb    anim	 q_barfer
# 00-01-Benchmark-demo-Results-non-swarm.ipynb  png	 tmax_animated.mp4
# 10-01-build-animator-container.ipynb	      png-maker  tony

# %%
#! cp png-maker/Dockerfile anim

# %%
#! ( cd /opt/npset/mylib/playLib; make build-root)

# %%
! pip3 install awscli
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
! mkdir -p tony
! ~/.local/bin/aws s3 cp s3://dev-rhassan/tony ./tony/ --recursive
# Out:
# download: s3://dev-rhassan/tony/tmax002.png to tony/tmax002.png
# download: s3://dev-rhassan/tony/tmax007.png to tony/tmax007.png
# download: s3://dev-rhassan/tony/tmax003.png to tony/tmax003.png
# download: s3://dev-rhassan/tony/tmax005.png to tony/tmax005.png
# download: s3://dev-rhassan/tony/tmax008.png to tony/tmax008.png
# download: s3://dev-rhassan/tony/tmax001.png to tony/tmax001.png
# download: s3://dev-rhassan/tony/tmax011.png to tony/tmax011.png
# download: s3://dev-rhassan/tony/tmax004.png to tony/tmax004.png
# download: s3://dev-rhassan/tony/tmax016.png to tony/tmax016.png
# download: s3://dev-rhassan/tony/tmax012.png to tony/tmax012.png
# download: s3://dev-rhassan/tony/tmax006.png to tony/tmax006.png
# download: s3://dev-rhassan/tony/tmax014.png to tony/tmax014.png
# download: s3://dev-rhassan/tony/tmax017.png to tony/tmax017.png
# download: s3://dev-rhassan/tony/tmax013.png to tony/tmax013.png
# download: s3://dev-rhassan/tony/tmax010.png to tony/tmax010.png
# ...

# %%
! ls ./tony
# Out:
# tmax001.png  tmax062.png  tmax123.png  tmax184.png  tmax245.png  tmax306.png
# tmax002.png  tmax063.png  tmax124.png  tmax185.png  tmax246.png  tmax307.png
# tmax003.png  tmax064.png  tmax125.png  tmax186.png  tmax247.png  tmax308.png
# tmax004.png  tmax065.png  tmax126.png  tmax187.png  tmax248.png  tmax309.png
# tmax005.png  tmax066.png  tmax127.png  tmax188.png  tmax249.png  tmax310.png
# tmax006.png  tmax067.png  tmax128.png  tmax189.png  tmax250.png  tmax311.png
# tmax007.png  tmax068.png  tmax129.png  tmax190.png  tmax251.png  tmax312.png
# tmax008.png  tmax069.png  tmax130.png  tmax191.png  tmax252.png  tmax313.png
# tmax009.png  tmax070.png  tmax131.png  tmax192.png  tmax253.png  tmax314.png
# tmax010.png  tmax071.png  tmax132.png  tmax193.png  tmax254.png  tmax315.png
# tmax011.png  tmax072.png  tmax133.png  tmax194.png  tmax255.png  tmax316.png
# tmax012.png  tmax073.png  tmax134.png  tmax195.png  tmax256.png  tmax317.png
# ...

# %%
! cat .gitignore
# Out:
# tony

# %%
'''
from playLib.bo_bucket import bo_get_bucket_list
bucket_name = 'dev-rhassan'
prefix = 'tony/'
file_list = bo_get_bucket_list(bucket_name, prefix)

file_list
'''
# Out:
# "\nfrom playLib.bo_bucket import bo_get_bucket_list\nbucket_name = 'dev-rhassan'\nprefix = 'tony/'\nfile_list = bo_get_bucket_list(bucket_name, prefix)\n\nfile_list\n"

# %%
import os
 
path = './tony'

file_list = []
 
files = os.listdir(path)
for name in files:
    #print(name)
    full_file = path +'/' + name
    file_list.append(full_file)
    

file_list.sort()

file_list
# Out:
# ['./tony/tmax001.png',
#  './tony/tmax002.png',
#  './tony/tmax003.png',
#  './tony/tmax004.png',
#  './tony/tmax005.png',
#  './tony/tmax006.png',
#  './tony/tmax007.png',
#  './tony/tmax008.png',
#  './tony/tmax009.png',
#  './tony/tmax010.png',
#  './tony/tmax011.png',
#  './tony/tmax012.png',
#  './tony/tmax013.png',
#  './tony/tmax014.png',
#  './tony/tmax015.png',
#  './tony/tmax016.png',
#  './tony/tmax017.png',
#  './tony/tmax018.png',
#  './tony/tmax019.png',
#  './tony/tmax020.png',
#  './tony/tmax021.png',
#  './tony/tmax022.png',
#  './tony/tmax023.png',
#  './tony/tmax024.png',
#  './tony/tmax025.png',
#  './tony/tmax026.png',
#  './tony/tmax027.png',
#  './tony/tmax028.png',
#  './tony/tmax029.png',
#  './tony/tmax030.png',
#  './tony/tmax031.png',
#  './tony/tmax032.png',
#  './tony/tmax033.png',
#  './tony/tmax034.png',
#  './tony/tmax035.png',
#  './tony/tmax036.png',
#  './tony/tmax037.png',
#  './tony/tmax038.png',
#  './tony/tmax039.png',
#  './tony/tmax040.png',
# ...

# %%
#import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.image as mgimg
# %matplotlib inline
#%matplotlib notebook

#fig = plt.figure()
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

ims=[]
for file in file_list:
    print(file)
    img = mgimg.imread(file)
    im = plt.imshow(img, animated=True)
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=200, blit=True,
                                repeat_delay=1000)

ani.save('tmax_animated.mp4')
# Out:
# ./tony/tmax001.png
# ./tony/tmax002.png
# ./tony/tmax003.png
# ./tony/tmax004.png
# ./tony/tmax005.png
# ./tony/tmax006.png
# ./tony/tmax007.png
# ./tony/tmax008.png
# ./tony/tmax009.png
# ./tony/tmax010.png
# ./tony/tmax011.png
# ./tony/tmax012.png
# ./tony/tmax013.png
# ./tony/tmax014.png
# ./tony/tmax015.png
# ./tony/tmax016.png
# ./tony/tmax017.png
# ./tony/tmax018.png
# ./tony/tmax019.png
# ./tony/tmax020.png
# ./tony/tmax021.png
# ./tony/tmax022.png
# ./tony/tmax023.png
# ./tony/tmax024.png
# ./tony/tmax025.png
# ./tony/tmax026.png
# ./tony/tmax027.png
# ./tony/tmax028.png
# ./tony/tmax029.png
# ./tony/tmax030.png
# ./tony/tmax031.png
# ./tony/tmax032.png
# ./tony/tmax033.png
# ./tony/tmax034.png
# ./tony/tmax035.png
# ./tony/tmax036.png
# ./tony/tmax037.png
# ./tony/tmax038.png
# ./tony/tmax039.png
# ./tony/tmax040.png
# ./tony/tmax041.png
# ./tony/tmax042.png
# ./tony/tmax043.png
# ./tony/tmax044.png
# ./tony/tmax045.png
# ./tony/tmax046.png
# ./tony/tmax047.png
# ...

# %% [markdown]
# # ffmpeg
# Thanks for the report @rmeno12 . We have a PR to fix the exception, but you will still have the problem that you do not have ffmpeg installed so will not be able to create an mp4 for you.

# %%
! sudo apt-get install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 108 not upgraded.

# %%
! ls
# Out:
# 00-00-DEMO-PNG-CREATION-to-S3-BUCKET.ipynb    anim	 q_barfer
# 00-01-Benchmark-demo-Results-non-swarm.ipynb  png	 tmax_animated.mp4
# 10-01-build-animator-container.ipynb	      png-maker  tony

# %%
#! pip install --user matplotlib
#! pip3 install --user ffmpeg

# %%
# from importlib import reload
# reload(matplotlib)

# %% [markdown]
# # Animate NOW!
#
# [animate push HERE](tmax_animated.mp4)

# %%
! ffmpeg -i tmax_animated.mp4 tmax_animated.gif
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %%
# !ls -lh *.mp4 *.gif
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 4.1M Apr 15 17:23 tmax_animated.gif
# -rw-rw-r-- 1 ubuntu ubuntu 755K Apr 15 17:20 tmax_animated.mp4

# %% [markdown]
# ![animate push HERE](tmax_animated.gif)
