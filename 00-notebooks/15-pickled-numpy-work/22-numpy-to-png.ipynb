# %%
import playLib
from playLib.pl_objects import Play

# %%
pl = Play()

# %%
! ls /mnt/ga-et-data/
# Out:
# Cloud_Veg_ET  MODIS_NDVI  a.tif  inputsv0  lunch  readme-bucket.md  steffi

# %%
#! ls /mnt/ga-et-data/Cloud_Veg_ET/Data/ETO

# %%
import numpy as np
import xarray as xr

# %%
from os import listdir
from os.path import isfile, join
mypath='/mnt/ga-et-data/Cloud_Veg_ET/Data/ETO'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
full_filename = mypath +'/' + onlyfiles[180]

ary = np.load(full_filename)

ary = np.flip(ary, axis=0)

ary[(ary<0)]=np.nan

# %%
import matplotlib.pyplot as plt

def display_my_var(ary):
    fig, ax = plt.subplots(1, 1, figsize=(14,12))

    mesh = ax.pcolormesh(ary,cmap='Set2')
    fig.colorbar(mesh)

    aspect=3/3
    #adjustable='box'
    ax.set_aspect(aspect)
    plt.gca().invert_yaxis()

# %%
display_my_var(ary)

# %%
# pl.pl_create_png?

# %%
pl.pl_create_png(fname='test.png',array_name=ary,cmap='Greens',xlabel='xaxis', ylabel='ylabel',title='ETOmiddle',subtitle='try2')

# %%
# !ls
# Out:
#  10-explore-numpy-via-s3fs.ipynb      22-numpy-to-png.ipynb   test.png
#  20-numpy-to-xarray.ipynb	      Readme.md
# '21-numpy-to-xarray-8bit int.ipynb'   confused.ipynb

# %% [markdown]
# ![test](./test.png)
