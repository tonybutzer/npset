tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo160.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo161.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo162.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo163.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo164.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo165.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo166.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo167.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo168.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo169.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo170.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo171.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo172.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo173.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo174.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo175.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo176.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo177.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo178.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo179.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo180.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo181.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo182.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:55 medianETo183.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo184.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo185.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo186.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo187.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo188.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo189.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo190.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo191.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo192.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo193.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo194.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo195.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo196.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo197.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo198.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo199.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo200.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo201.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo202.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo203.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo204.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo205.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo206.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo207.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo208.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo209.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo210.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo211.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo212.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo213.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo214.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo215.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo216.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo217.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo218.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo219.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo220.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo221.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo222.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo223.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo224.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo225.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo226.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo227.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo228.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo229.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo230.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo231.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo232.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo233.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo234.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo235.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo236.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo237.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo238.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo239.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo240.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo241.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo242.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo243.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo244.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo245.tif_gw.npy
# -rwxr-xr-x 1 root root 24217376 Mar 17 22:56 medianETo246.tif_gw.npy

# %% [markdown]
# # Reference
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.savez.html
#
#
# The .npz file format is a zipped archive of files named after the variables they contain. The archive is not compressed and each file in the archive contains one variable in .npy format. For a description of the .npy format, see numpy.lib.format.
#
# When opening the saved .npz file with load a NpzFile object is returned. This is a dictionary-like object which can be queried for its list of arrays (with the .files attribute), and for the arrays themselves.

# %%
import numpy as np
help(np.load)
# Out:
# Help on function load in module numpy:
#
# load(file, mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')
#     Load arrays or pickled objects from ``.npy``, ``.npz`` or pickled files.
#
#     .. warning:: Loading files that contain object arrays uses the ``pickle``
#                  module, which is not secure against erroneous or maliciously
#                  constructed data. Consider passing ``allow_pickle=False`` to
#                  load data that is known not to contain object arrays for the
#                  safer handling of untrusted sources.
#
#     Parameters
#     ----------
#     file : file-like object, string, or pathlib.Path
#         The file to read. File-like objects must support the
#         ``seek()`` and ``read()`` methods. Pickled files require that the
#         file-like object support the ``readline()`` method as well.
#     mmap_mode : {None, 'r+', 'r', 'w+', 'c'}, optional
#         If not None, then memory-map the file, using the given mode (see
#         `numpy.memmap` for a detailed description of the modes).  A
#         memory-mapped array is kept on disk. However, it can be accessed
#         and sliced like any ndarray.  Memory mapping is especially useful
#         for accessing small fragments of large files without reading the
#         entire file into memory.
#     allow_pickle : bool, optional
#         Allow loading pickled object arrays stored in npy files. Reasons for
#         disallowing pickles include security, as loading pickled data can
#         execute arbitrary code. If pickles are disallowed, loading object
#         arrays will fail. Default: False
#
#         .. versionchanged:: 1.16.3
#             Made default False in response to CVE-2019-6446.
#
#     fix_imports : bool, optional
#         Only useful when loading Python 2 generated pickled files on Python 3,
#         which includes npy/npz files containing object arrays. If `fix_imports`
#         is True, pickle will try to map the old Python 2 names to the new names
#         used in Python 3.
#     encoding : str, optional
#         What encoding to use when reading Python 2 strings. Only useful when
#         loading Python 2 generated pickled files in Python 3, which includes
#         npy/npz files containing object arrays. Values other than 'latin1',
#         'ASCII', and 'bytes' are not allowed, as they can corrupt numerical
#         data. Default: 'ASCII'
#
#     Returns
#     -------
#     result : array, tuple, dict, etc.
#         Data stored in the file. For ``.npz`` files, the returned instance
#         of NpzFile class must be closed to avoid leaking file descriptors.
#
#     Raises
#     ------
#     IOError
#         If the input file does not exist or cannot be read.
#     ValueError
#         The file contains an object array, but allow_pickle=False given.
#
#     See Also
#     --------
#     save, savez, savez_compressed, loadtxt
#     memmap : Create a memory-map to an array stored in a file on disk.
#     lib.format.open_memmap : Create or load a memory-mapped ``.npy`` file.
#
#     Notes
#     -----
#     - If the file contains pickle data, then whatever object is stored
#       in the pickle is returned.
#     - If the file is a ``.npy`` file, then a single array is returned.
#     - If the file is a ``.npz`` file, then a dictionary-like object is
#       returned, containing ``{filename: array}`` key-value pairs, one for
#       each file in the archive.
#     - If the file is a ``.npz`` file, the returned value supports the
#       context manager protocol in a similar fashion to the open function::
#
#         with load('foo.npz') as data:
#             a = data['a']
#
#       The underlying file descriptor is closed when exiting the 'with'
#       block.
#
#     Examples
#     --------
#     Store data to disk, and load it again:
#
#     >>> np.save('/tmp/123', np.array([[1, 2, 3], [4, 5, 6]]))
#     >>> np.load('/tmp/123.npy')
#     array([[1, 2, 3],
#            [4, 5, 6]])
#
#     Store compressed data to disk, and load it again:
#
#     >>> a=np.array([[1, 2, 3], [4, 5, 6]])
#     >>> b=np.array([1, 2])
#     >>> np.savez('/tmp/123.npz', a=a, b=b)
#     >>> data = np.load('/tmp/123.npz')
#     >>> data['a']
#     array([[1, 2, 3],
#            [4, 5, 6]])
#     >>> data['b']
#     array([1, 2])
#     >>> data.close()
#
#     Mem-map the stored array, and then access the second row
#     directly from disk:
#
#     >>> X = np.load('/tmp/123.npy', mmap_mode='r')
#     >>> X[1, :]
#     memmap([4, 5, 6])

# %%
s3fs_fuse_mounted_file_path = '/mnt/ga-et-data/Cloud_Veg_ET/Data/ETO/'
pickled_eto_data_file = 'medianETo246.tif_gw.npy'

full_filename = s3fs_fuse_mounted_file_path + pickled_eto_data_file

median_eto_day_246_array = np.load(full_filename)

# %%
ary = median_eto_day_246_array

# %%
ary.shape
# Out:
# (3124, 1938)

# %%
last_file_shape=ary.shape

# %%
ary.max()
# Out:
# 5.0655947

# %%
ary.min()
# Out:
# -3.4028235e+38

# %%
from rasterio.plot import show_hist
#show_hist(ary, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram")

# %%
ary
# Out:
# array([[-3.4028235e+38, -3.4028235e+38, -3.4028235e+38, ...,
#          3.6485620e+00,  3.6485620e+00,  3.6485620e+00],
#        [-3.4028235e+38, -3.4028235e+38, -3.4028235e+38, ...,
#          3.6485620e+00,  3.6485620e+00,  3.6485620e+00],
#        [-3.4028235e+38, -3.4028235e+38, -3.4028235e+38, ...,
#          3.6831279e+00,  3.6831279e+00,  3.6831279e+00],
#        ...,
#        [ 4.2643900e+00,  4.2643900e+00,  4.2643900e+00, ...,
#         -3.4028235e+38, -3.4028235e+38, -3.4028235e+38],
#        [ 4.2643900e+00,  4.2643900e+00,  4.2643900e+00, ...,
#         -3.4028235e+38, -3.4028235e+38, -3.4028235e+38],
#        [ 4.2643900e+00,  4.2643900e+00,  4.2643900e+00, ...,
#         -3.4028235e+38, -3.4028235e+38, -3.4028235e+38]], dtype=float32)

# %%
ary[(ary < 0)] = np.nan

# %%
show_hist(ary, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram")
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/tljh/user/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(10, 8))

mesh = ax.pcolormesh(ary,cmap='magma')
fig.colorbar(mesh)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(6, 10))

mesh = ax.pcolormesh(ary,cmap='magma')
fig.colorbar(mesh)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

mesh = ax.pcolormesh(ary,cmap='magma')
fig.colorbar(mesh)

aspect=ary.shape[0]/ary.shape[1]
adjustable='box'
ax.set_aspect(aspect, adjustable=adjustable)
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))

mesh = ax.pcolormesh(ary,cmap='CMRmap')
fig.colorbar(mesh)

aspect=ary.shape[0]/ary.shape[1]
adjustable='box'
ax.set_aspect(aspect, adjustable=adjustable)
plt.gca().invert_yaxis()

# %% [markdown]
# ![](https://s3.amazonaws.com/american-rivers-website/wp-content/uploads/2016/03/27005910/DelawareRiverBasin-01-302x350.png)

# %%
fig, ax = plt.subplots(1, 1, figsize=(14,12))

mesh = ax.pcolormesh(ary,cmap='Set2')
fig.colorbar(mesh)

aspect=3/2
adjustable='box'
ax.set_aspect(aspect, adjustable=adjustable)
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots(1, 1, figsize=(14,12))

mesh = ax.pcolormesh(ary,cmap='Set2')
fig.colorbar(mesh)

aspect=3/2.5
#adjustable='box'
ax.set_aspect(aspect)
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots(1, 1, figsize=(14,12))

mesh = ax.pcolormesh(ary,cmap='Set2')
fig.colorbar(mesh)

aspect=3/3
#adjustable='box'
ax.set_aspect(aspect)
plt.gca().invert_yaxis()

# %% [markdown]
# ![](https://www.state.nj.us/drbc/library/images/maps/drb_illustration.jpg)

# %%
s3fs_fuse_mounted_file_path = '/mnt/ga-et-data/Cloud_Veg_ET/Data/ETO/'
pickled_eto_data_file = 'medianETo001.tif_gw.npy'

full_filename = s3fs_fuse_mounted_file_path + pickled_eto_data_file

median_eto_day_1_array = np.load(full_filename)

# %%
ary = median_eto_day_1_array

# %%
ary[(ary < 0)] = np.nan

# %%
fig, ax = plt.subplots(1, 1, figsize=(14,12))

mesh = ax.pcolormesh(ary,cmap='Set2')
fig.colorbar(mesh)

aspect=3/3
#adjustable='box'
ax.set_aspect(aspect)
plt.gca().invert_yaxis()

# %% [markdown]
# ![](https://s3.amazonaws.com/american-rivers-website/wp-content/uploads/2016/03/27005910/DelawareRiverBasin-01-302x350.png)

# %%
fig, ax = plt.subplots(1, 1, figsize=(14,12))

mesh = ax.pcolormesh(ary,cmap='CMRmap')
fig.colorbar(mesh)

#aspect=ary.shape[0]/ary.shape[1]
#adjustable='box'
#ax.set_aspect(aspect, adjustable=adjustable)
plt.gca().invert_yaxis()

# %%
last_file_shape
# Out:
# (3124, 1938)

# %%
ary.shape
# Out:
# (3124, 1938)

# %%
if last_file_shape == ary.shape:
    print('YAY!')
# Out:
# YAY!
