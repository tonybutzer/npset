# %% [markdown]
# # Failed to readthis type of soil data

# %%
# %env CURL_CA_BUNDLE=/etc/ssl/certs/ca-certificates.crt
# Out:
# env: CURL_CA_BUNDLE=/etc/ssl/certs/ca-certificates.crt

# %%
import rasterio
tif_file = '/vsis3/ga-et-data/inputsv0/soilData/Soil_saturation_us.tif'
with rasterio.open(tif_file) as src:
    myThumb = src.read(1, out_shape=(1, int(src.height // 16), int(src.width // 16)))

print(myThumb.shape)
pyplot.imshow(myThumb, cmap='magma')

pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsis3/ga-et-data/inputsv0/soilData/Soil_saturation_us.tif' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-5-37632ee2f561> in <module>
#       1 import rasterio
#       2 tif_file = '/vsis3/ga-et-data/inputsv0/soilData/Soil_saturation_us.tif'
# ----> 3 with rasterio.open(tif_file) as src:
#       4     myThumb = src.read(1, out_shape=(1, int(src.height // 16), int(src.width // 16)))
#       5
#
# /opt/tljh/user/lib/python3.7/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     432
#     433         with env_ctor(session=session):
# --> 434             return f(*args, **kwds)
#     435
#     436     return wrapper
#
# /opt/tljh/user/lib/python3.7/site-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     217         # None.
#     218         if mode == 'r':
# --> 219             s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     220         elif mode == 'r+':
#     221             s = get_writer_for_path(path)(path, mode, driver=driver, sharing=sharing, **kwargs)
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: '/vsis3/ga-et-data/inputsv0/soilData/Soil_saturation_us.tif' does not exist in the file system, and is not recognized as a supported dataset name.

# %%
#!time aws s3 cp s3://ga-et-data/inputsv0/soilData/Soil_saturation_us.tif s3://ga-et-data/inputsv0/soilData/tonysat.tif
# Out:
# copy: s3://ga-et-data/inputsv0/soilData/Soil_saturation_us.tif to s3://ga-et-data/inputsv0/soilData/tonysat.tif
# 2.85user 0.29system 0:26.76elapsed 11%CPU (0avgtext+0avgdata 64700maxresident)k
# 0inputs+0outputs (0major+27484minor)pagefaults 0swaps

# %%
from matplotlib import pyplot

# %%
import rasterio
tif_file = '/vsis3/ga-et-data/inputsv0/soilData/tonysat.tif'
with rasterio.open(tif_file) as src:
    myThumb = src.read(1, out_shape=(1, int(src.height // 16), int(src.width // 16)))

print(myThumb.shape)
pyplot.imshow(myThumb, cmap='magma')

pyplot.show()
# Out:
# (1683, 2886)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e7e1bc78df45> in <module>
#       5
#       6 print(myThumb.shape)
# ----> 7 pyplot.imshow(myThumb, cmap='magma')
#       8
#       9 pyplot.show()
#
# NameError: name 'pyplot' is not defined

# %%
pyplot.imshow(myThumb, cmap='magma')

pyplot.show()

# %%
import numpy as np
array = myThumb
array[(array < 0)] = np.nan

# %%
pyplot.imshow(array, cmap='magma')

pyplot.show()

# %%
pyplot.imshow(array, cmap='prism')

pyplot.show()
