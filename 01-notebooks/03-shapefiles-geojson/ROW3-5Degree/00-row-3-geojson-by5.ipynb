# %%
row_3_040N = {
       'ul_lat' : 40.0,
       'lr_lat' : 35.0,
       'start_lon' : -130.0,
       'end_lon' : -80.0,
       'increment' : 5
   }

# %%
#r0 = row_0_070N
#r0=row_2_050N
r0=row_3_040N
for lonval in range(int(r0['start_lon']), int(r0['end_lon']+r0['increment']), r0['increment']):
    print (lonval)
# Out:
# -130
# -125
# -120
# -115
# -110
# -105
# -100
# -95
# -90
# -85
# -80

# %%
def make_poly(row_dict, ul_lon):
    coord_list = []
    r = row_dict
    ul_lon_lat = [ul_lon, r['ul_lat']]
    ur_lon_lat = [ul_lon + r['increment'], r['ul_lat']]
    lr_lon_lat = [ul_lon + r['increment'], r['lr_lat']]
    ll_lon_lat = [ul_lon, r['lr_lat']]
    print (ul_lon_lat)
    coord_list.append(ul_lon_lat)
    print (ur_lon_lat)
    coord_list.append(ur_lon_lat)
    print (lr_lon_lat)
    coord_list.append(lr_lon_lat)
    print (ll_lon_lat)
    coord_list.append(ll_lon_lat)
    print (ul_lon_lat)
    coord_list.append(ul_lon_lat)
    return(coord_list)

# %%
ul_lon = -130.0
coords = make_poly(r0, ul_lon)
# Out:
# [-130.0, 40.0]
# [-125.0, 40.0]
# [-125.0, 35.0]
# [-130.0, 35.0]
# [-130.0, 40.0]

# %%
coords
# Out:
# [[-130.0, 40.0],
#  [-125.0, 40.0],
#  [-125.0, 35.0],
#  [-130.0, 35.0],
#  [-130.0, 40.0]]

# %%
polycs = []
polycs.append(coords)

# %%
import json
geos = []
for polyc in polycs:
    poly = {
        'type': 'Feature',
        'properties': {},
        'geometry': {
            'type': 'Polygon',
            'coordinates': [polyc]
        }
    }
    geos.append(poly)

geometries = {
    'type': 'FeatureCollection',
    'features': geos,
}

geo_str = json.dumps(geometries)

# %%
geo_str
# Out:
# '{"type": "FeatureCollection", "features": [{"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-130.0, 40.0], [-125.0, 40.0], [-125.0, 35.0], [-130.0, 35.0], [-130.0, 40.0]]]}}]}'

# %%
import pprint
pp = pprint.PrettyPrinter()
pp.pprint(geo_str)
# Out:
# ('{"type": "FeatureCollection", "features": [{"type": "Feature", "properties": '
#  '{}, "geometry": {"type": "Polygon", "coordinates": [[[-130.0, 40.0], '
#  '[-125.0, 40.0], [-125.0, 35.0], [-130.0, 35.0], [-130.0, 40.0]]]}}]}')

# %%
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(geometries)
# Out:
# { 'features': [ { 'geometry': { 'coordinates': [ [ [-130.0, 40.0],
#                                                    [-125.0, 40.0],
#                                                    [-125.0, 35.0],
#                                                    [-130.0, 35.0],
#                                                    [-130.0, 40.0]]],
#                                 'type': 'Polygon'},
#                   'properties': {},
#                   'type': 'Feature'}],
#   'type': 'FeatureCollection'}

# %%
f = open("demofile3.txt", "w")
f.write(geo_str)
f.close()

#open and read the file after the appending:
f = open("demofile3.txt", "r")
print(f.read())
# Out:
# {"type": "FeatureCollection", "features": [{"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-130.0, 40.0], [-125.0, 40.0], [-125.0, 35.0], [-130.0, 35.0], [-130.0, 40.0]]]}}]}

# %%
! cat demofile3.txt | python3 -m json.tool
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -130.0,
#                             40.0
#                         ],
#                         [
#                             -125.0,
#                             40.0
#                         ],
#                         [
#                             -125.0,
#                             35.0
#                         ],
#                         [
#                             -130.0,
#                             35.0
#                         ],
#                         [
#                             -130.0,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         }
#     ]
# }

# %%
r0 = row_3_040N
polycs = []
for lonval in range(int(r0['start_lon']), int(r0['end_lon']+r0['increment']), r0['increment']):
    print (lonval)
    coords = make_poly(r0, lonval)
    polycs.append(coords)
# Out:
# -130
# [-130, 40.0]
# [-125, 40.0]
# [-125, 35.0]
# [-130, 35.0]
# [-130, 40.0]
# -125
# [-125, 40.0]
# [-120, 40.0]
# [-120, 35.0]
# [-125, 35.0]
# [-125, 40.0]
# -120
# [-120, 40.0]
# [-115, 40.0]
# [-115, 35.0]
# [-120, 35.0]
# [-120, 40.0]
# -115
# [-115, 40.0]
# [-110, 40.0]
# [-110, 35.0]
# [-115, 35.0]
# [-115, 40.0]
# -110
# [-110, 40.0]
# [-105, 40.0]
# [-105, 35.0]
# [-110, 35.0]
# [-110, 40.0]
# -105
# [-105, 40.0]
# [-100, 40.0]
# [-100, 35.0]
# [-105, 35.0]
# [-105, 40.0]
# -100
# [-100, 40.0]
# [-95, 40.0]
# [-95, 35.0]
# [-100, 35.0]
# [-100, 40.0]
# -95
# [-95, 40.0]
# [-90, 40.0]
# [-90, 35.0]
# [-95, 35.0]
# [-95, 40.0]
# -90
# [-90, 40.0]
# [-85, 40.0]
# [-85, 35.0]
# [-90, 35.0]
# [-90, 40.0]
# -85
# [-85, 40.0]
# [-80, 40.0]
# [-80, 35.0]
# [-85, 35.0]
# [-85, 40.0]
# -80
# [-80, 40.0]
# [-75, 40.0]
# [-75, 35.0]
# [-80, 35.0]
# [-80, 40.0]

# %%
import json
geos = []
for polyc in polycs:
    poly = {
        'type': 'Feature',
        'properties': {},
        'geometry': {
            'type': 'Polygon',
            'coordinates': [polyc]
        }
    }
    geos.append(poly)

geometries = {
    'type': 'FeatureCollection',
    'features': geos,
}

geo_str = json.dumps(geometries)

# %%
geo_str
# Out:
# '{"type": "FeatureCollection", "features": [{"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-130, 40.0], [-125, 40.0], [-125, 35.0], [-130, 35.0], [-130, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-125, 40.0], [-120, 40.0], [-120, 35.0], [-125, 35.0], [-125, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-120, 40.0], [-115, 40.0], [-115, 35.0], [-120, 35.0], [-120, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-115, 40.0], [-110, 40.0], [-110, 35.0], [-115, 35.0], [-115, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-110, 40.0], [-105, 40.0], [-105, 35.0], [-110, 35.0], [-110, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-105, 40.0], [-100, 40.0], [-100, 35.0], [-105, 35.0], [-105, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-100, 40.0], [-95, 40.0], [-95, 35.0], [-100, 35.0], [-100, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-95, 40.0], [-90, 40.0], [-90, 35.0], [-95, 35.0], [-95, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-90, 40.0], [-85, 40.0], [-85, 35.0], [-90, 35.0], [-90, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-85, 40.0], [-80, 40.0], [-80, 35.0], [-85, 35.0], [-85, 40.0]]]}}, {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-80, 40.0], [-75, 40.0], [-75, 35.0], [-80, 35.0], [-80, 40.0]]]}}]}'

# %%
import json
with open('row3.json', 'w', encoding='utf-8') as f:
    json.dump(geometries, f, ensure_ascii=False, indent=4)

# %%
! cat row3.json
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -130,
#                             40.0
#                         ],
#                         [
#                             -125,
#                             40.0
#                         ],
#                         [
#                             -125,
#                             35.0
#                         ],
#                         [
#                             -130,
#                             35.0
#                         ],
#                         [
#                             -130,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -125,
#                             40.0
#                         ],
#                         [
#                             -120,
#                             40.0
#                         ],
#                         [
#                             -120,
#                             35.0
#                         ],
#                         [
#                             -125,
#                             35.0
#                         ],
#                         [
#                             -125,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -120,
#                             40.0
#                         ],
#                         [
#                             -115,
#                             40.0
#                         ],
#                         [
#                             -115,
#                             35.0
#                         ],
#                         [
#                             -120,
#                             35.0
#                         ],
#                         [
#                             -120,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -115,
#                             40.0
#                         ],
#                         [
#                             -110,
#                             40.0
#                         ],
#                         [
#                             -110,
#                             35.0
#                         ],
#                         [
#                             -115,
#                             35.0
#                         ],
#                         [
#                             -115,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -110,
#                             40.0
#                         ],
#                         [
#                             -105,
#                             40.0
#                         ],
#                         [
#                             -105,
#                             35.0
#                         ],
#                         [
#                             -110,
#                             35.0
#                         ],
#                         [
#                             -110,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -105,
#                             40.0
#                         ],
#                         [
#                             -100,
#                             40.0
#                         ],
#                         [
#                             -100,
#                             35.0
#                         ],
#                         [
#                             -105,
#                             35.0
#                         ],
#                         [
#                             -105,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -100,
#                             40.0
#                         ],
#                         [
#                             -95,
#                             40.0
#                         ],
#                         [
#                             -95,
#                             35.0
#                         ],
#                         [
#                             -100,
#                             35.0
#                         ],
#                         [
#                             -100,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -95,
#                             40.0
#                         ],
#                         [
#                             -90,
#                             40.0
#                         ],
#                         [
#                             -90,
#                             35.0
#                         ],
#                         [
#                             -95,
#                             35.0
#                         ],
#                         [
#                             -95,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -90,
#                             40.0
#                         ],
#                         [
#                             -85,
#                             40.0
#                         ],
#                         [
#                             -85,
#                             35.0
#                         ],
#                         [
#                             -90,
#                             35.0
#                         ],
#                         [
#                             -90,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -85,
#                             40.0
#                         ],
#                         [
#                             -80,
#                             40.0
#                         ],
#                         [
#                             -80,
#                             35.0
#                         ],
#                         [
#                             -85,
#                             35.0
#                         ],
#                         [
#                             -85,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {},
#             "geometry": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -80,
#                             40.0
#                         ],
#                         [
#                             -75,
#                             40.0
#                         ],
#                         [
#                             -75,
#                             35.0
#                         ],
#                         [
#                             -80,
#                             35.0
#                         ],
#                         [
#                             -80,
#                             40.0
#                         ]
#                     ]
#                 ]
#             }
#         }
#     ]
# }

# %%
import json
def w_geojson(filename,polyc):
    geos = []

    poly = {
        'type': 'Feature',
        'properties': {},
        'geometry': {
            'type': 'Polygon',
            'coordinates': [polyc]
        }
    }
    geos.append(poly)

    geometries = {
        'type': 'FeatureCollection',
        'features': geos,
    }

    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(geometries, f, ensure_ascii=False, indent=4)

# %%
import os
def w_shape(filename):
    shp_filename = filename.split('.json')[0] + '.shp'
    print(filename,shp_filename)
    cmd='ogr2ogr -f \"ESRI Shapefile\" {} {}'.format(shp_filename, filename)
    os.system(cmd)

# %%
for polyc in polycs:
    print (polyc)
    filename = str(int(polyc[0][1])) +'N' + str(int(polyc[0][0])) +'E.json'
    print(filename)
    print('---'*20)
    w_geojson(filename,polyc)
    w_shape(filename)
# Out:
# [[-130, 40.0], [-125, 40.0], [-125, 35.0], [-130, 35.0], [-130, 40.0]]
# 40N-130E.json
# ------------------------------------------------------------
# 40N-130E.json 40N-130E.shp
# [[-125, 40.0], [-120, 40.0], [-120, 35.0], [-125, 35.0], [-125, 40.0]]
# 40N-125E.json
# ------------------------------------------------------------
# 40N-125E.json 40N-125E.shp
# [[-120, 40.0], [-115, 40.0], [-115, 35.0], [-120, 35.0], [-120, 40.0]]
# 40N-120E.json
# ------------------------------------------------------------
# 40N-120E.json 40N-120E.shp
# [[-115, 40.0], [-110, 40.0], [-110, 35.0], [-115, 35.0], [-115, 40.0]]
# 40N-115E.json
# ------------------------------------------------------------
# 40N-115E.json 40N-115E.shp
# [[-110, 40.0], [-105, 40.0], [-105, 35.0], [-110, 35.0], [-110, 40.0]]
# 40N-110E.json
# ------------------------------------------------------------
# 40N-110E.json 40N-110E.shp
# [[-105, 40.0], [-100, 40.0], [-100, 35.0], [-105, 35.0], [-105, 40.0]]
# 40N-105E.json
# ------------------------------------------------------------
# 40N-105E.json 40N-105E.shp
# [[-100, 40.0], [-95, 40.0], [-95, 35.0], [-100, 35.0], [-100, 40.0]]
# 40N-100E.json
# ------------------------------------------------------------
# 40N-100E.json 40N-100E.shp
# [[-95, 40.0], [-90, 40.0], [-90, 35.0], [-95, 35.0], [-95, 40.0]]
# 40N-95E.json
# ------------------------------------------------------------
# 40N-95E.json 40N-95E.shp
# [[-90, 40.0], [-85, 40.0], [-85, 35.0], [-90, 35.0], [-90, 40.0]]
# 40N-90E.json
# ------------------------------------------------------------
# 40N-90E.json 40N-90E.shp
# [[-85, 40.0], [-80, 40.0], [-80, 35.0], [-85, 35.0], [-85, 40.0]]
# 40N-85E.json
# ------------------------------------------------------------
# 40N-85E.json 40N-85E.shp
# [[-80, 40.0], [-75, 40.0], [-75, 35.0], [-80, 35.0], [-80, 40.0]]
# 40N-80E.json
# ------------------------------------------------------------
# 40N-80E.json 40N-80E.shp

# %%
# !ls
# Out:
# 00-row-3-geojson-by5.ipynb  40N-110E.shx   40N-125E.shx   40N-85E.shx
# 40N-100E.dbf		    40N-115E.dbf   40N-130E.dbf   40N-90E.dbf
# 40N-100E.json		    40N-115E.json  40N-130E.json  40N-90E.json
# 40N-100E.prj		    40N-115E.prj   40N-130E.prj   40N-90E.prj
# 40N-100E.shp		    40N-115E.shp   40N-130E.shp   40N-90E.shp
# 40N-100E.shx		    40N-115E.shx   40N-130E.shx   40N-90E.shx
# 40N-105E.dbf		    40N-120E.dbf   40N-80E.dbf	  40N-95E.dbf
# 40N-105E.json		    40N-120E.json  40N-80E.json   40N-95E.json
# 40N-105E.prj		    40N-120E.prj   40N-80E.prj	  40N-95E.prj
# 40N-105E.shp		    40N-120E.shp   40N-80E.shp	  40N-95E.shp
# 40N-105E.shx		    40N-120E.shx   40N-80E.shx	  40N-95E.shx
# 40N-110E.dbf		    40N-125E.dbf   40N-85E.dbf	  demofile3.txt
# 40N-110E.json		    40N-125E.json  40N-85E.json   row3.json
# 40N-110E.prj		    40N-125E.prj   40N-85E.prj
# 40N-110E.shp		    40N-125E.shp   40N-85E.shp
